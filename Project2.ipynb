# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import collections
import math
import os
import random
import zipfile

import numpy as np
from six.moves import urllib
from six.moves import xrange
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/compat/v2_compat.py:111: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
url = 'http://mattmahoney.net/dc/'

# %%
def download_file(filename, expected_bytes):
  if not os.path.exists(filename):
    filename, _ = urllib.request.urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified', filename)
  else:
    print(statinfo.st_size)
    raise Exception(
        'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

# %%
filename = download_file('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words."""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data

vocabulary = read_data(filename)
print('Data size', len(vocabulary))
# Out:
# Data size 17005207

# %%
vocabulary_size = 50000
def build_dataset(words, n_words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(n_words - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0 
      unk_count += 1
    data.append(index)
  count[0][1] = unk_count
  reversed_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
  return data, count, dictionary, reversed_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(vocabulary, vocabulary_size)
del vocabulary  
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10], [reverse_dictionary[i] for i in data[:10]])

data_index = 0
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156] ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %%
def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1  
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window 
    targets_to_avoid = [skip_window]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  data_index = (data_index + len(data) - span) % len(data)
  return batch, labels

batch, labels = generate_batch(batch_size=8, num_skips=2, skip_window=1)
for i in range(8):
  print(batch[i], reverse_dictionary[batch[i]], '->', labels[i, 0], reverse_dictionary[labels[i, 0]])
# Out:
# 3081 originated -> 5234 anarchism
# 3081 originated -> 12 as
# 12 as -> 3081 originated
# 12 as -> 6 a
# 6 a -> 195 term
# 6 a -> 12 as
# 195 term -> 6 a
# 195 term -> 2 of

# %%
batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
skip_window = 1       
num_skips = 2         

valid_size = 16     
valid_window = 100  
valid_examples = np.random.choice(valid_window, valid_size, replace=False)
num_sampled = 64

# %%
graph = tf.Graph()

with graph.as_default():

  # Input data.
  train_inputs = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

  with tf.device('/cpu:0'):
    embeddings = tf.Variable(
        tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    embed = tf.nn.embedding_lookup(embeddings, train_inputs)

    nce_weights = tf.Variable(
        tf.truncated_normal([vocabulary_size, embedding_size],
                            stddev=1.0 / math.sqrt(embedding_size)))
    nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

  loss = tf.reduce_mean(
      tf.nn.nce_loss(weights=nce_weights,
                     biases=nce_biases,
                     labels=train_labels,
                     inputs=embed,
                     num_sampled=num_sampled,
                     num_classes=vocabulary_size))

  optimizer = tf.train.GradientDescentOptimizer(1.0).minimize(loss)

  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
      normalized_embeddings, valid_dataset)
  similarity = tf.matmul(
      valid_embeddings, normalized_embeddings, transpose_b=True)

  init = tf.global_variables_initializer()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1096: calling reduce_sum_v1 (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  init.run()
  print('Initialized')

  average_loss = 0
  for step in xrange(num_steps):
    batch_inputs, batch_labels = generate_batch(
        batch_size, num_skips, skip_window)
    feed_dict = {train_inputs: batch_inputs, train_labels: batch_labels}

    _, loss_val = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += loss_val

    if step % 2000 == 0:
      if step > 0:
        average_loss /= 2000
      print('Average loss at step ', step, ': ', average_loss)
      average_loss = 0

    if step % 10000 == 0:
      sim = similarity.eval()
      for i in xrange(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 
        nearest = (-sim[i, :]).argsort()[1:top_k + 1]
        log_str = 'Nearest to %s:' % valid_word
        for k in xrange(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log_str = '%s %s,' % (log_str, close_word)
        print(log_str)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step  0 :  275.44677734375
# Nearest to b: identities, bok, rood, thirteenth, hispaniola, trench, hagar, baritone,
# Nearest to four: landfall, pekka, vignettes, ridinghood, nagy, heiress, paradoxically, motivate,
# Nearest to nine: sowell, flowered, senegal, szabo, ertegun, unprovoked, emirates, kansas,
# Nearest to can: hopeful, universit, quite, un, vangelis, kurtz, intv, unlikely,
# Nearest to on: unwittingly, evoking, farming, saa, autographs, kekkonen, stabilizing, samaritan,
# Nearest to had: palmerston, doha, trait, ordered, patristic, vfr, symmetric, unexpected,
# Nearest to for: parents, consummated, meteors, baile, turtle, jhanas, idiot, hub,
# Nearest to has: kenneth, meinhof, earths, orphanage, pareto, bequest, canary, mappings,
# Nearest to the: misfortunes, ouadda, gis, gloomy, finnegans, thumb, eukaryotic, motocross,
# Nearest to this: miquelon, loci, scorpius, py, support, notation, aries, spain,
# Nearest to i: impartial, regalia, milieu, trna, bannockburn, cyclists, badge, coping,
# Nearest to history: rus, flare, voices, cel, worried, primers, appoint, luther,
# Nearest to time: doc, ics, isostatic, tae, weishaupt, flavors, consumed, deviating,
# Nearest to use: serfdom, helsingborg, eschew, halogens, gc, tangier, eurocard, dalton,
# Nearest to during: cell, judge, canals, lazuli, jethro, dieppe, disturbance, mayoral,
# Nearest to so: dollfuss, unpaved, incrementing, abingdon, professional, citrus, obstruction, czes,
# Average loss at step  2000 :  113.55915539884568
# Average loss at step  4000 :  53.15570557451248
# Average loss at step  6000 :  33.143023879528045
# Average loss at step  8000 :  23.367175027132035
# Average loss at step  10000 :  17.80834670472145
# Nearest to b: trench, vogt, thirteenth, agnetha, entire, regarded, maneuver, chlorine,
# Nearest to four: zero, fao, six, basins, aberdeenshire, archie, nine, five,
# Nearest to nine: zero, altenberg, phi, eight, basins, vs, seven, one,
# Nearest to can: hopeful, quite, bracelet, un, unlikely, kurtz, gb, female,
# Nearest to on: in, and, unwittingly, to, hakama, of, genera, from,
# Nearest to had: phi, and, complications, was, is, did, trait, min,
# Nearest to for: in, of, and, with, as, plant, is, to,
# Nearest to has: bequest, is, conspiracy, abu, kenneth, recommend, left, separating,
# Nearest to the: a, UNK, and, alien, one, an, aberdeenshire, lymphoma,
# Nearest to this: a, aries, the, support, loose, atemi, spain, lymphoma,
# Nearest to i: badge, lymphoma, explicitly, safe, legality, finnish, decision, claude,
# Nearest to history: appoint, worried, luther, originates, bckgr, arise, unit, archie,
# Nearest to time: shift, phi, apollo, faith, gland, rez, consumed, mid,
# Nearest to use: coke, bckgr, february, stick, changed, populated, throughout, argentine,
# Nearest to during: judge, cell, in, word, canals, tissue, side, disturbance,
# Nearest to so: unpaved, dollfuss, professional, develop, change, running, english, phillips,
# Average loss at step  12000 :  14.047556442379951
# Average loss at step  14000 :  11.942641927719116
# Average loss at step  16000 :  9.8331219997406
# Average loss at step  18000 :  8.59768661725521
# Average loss at step  20000 :  7.9618630900383
# Nearest to b: trench, d, identities, batll, and, vogt, conductor, acapulco,
# Nearest to four: zero, six, nine, eight, seven, five, three, two,
# Nearest to nine: eight, six, zero, seven, five, four, three, agouti,
# Nearest to can: hopeful, quite, unlikely, specimens, would, bracelet, to, universit,
# Nearest to on: in, and, unwittingly, operatorname, two, by, agouti, from,
# Nearest to had: was, is, have, has, did, phi, agouti, and,
# Nearest to for: in, and, of, with, to, as, dasyprocta, apatosaurus,
# Nearest to has: was, is, had, bequest, have, earths, kenneth, conspiracy,
# Nearest to the: a, his, their, its, this, one, alphorn, aberdeenshire,
# Nearest to this: the, a, it, aries, three, operatorname, support, lymphoma,
# Nearest to i: dasyprocta, lymphoma, stock, safe, legality, claude, suffix, badge,
# Nearest to history: appoint, originates, luther, dasyprocta, worried, abdomen, apologia, commercials,
# Nearest to time: shift, dasyprocta, agouti, phi, cistercian, fathers, gland, faith,
# Nearest to use: serfdom, circ, coke, operatorname, bckgr, february, stick, enrich,
# Nearest to during: in, judge, of, cell, at, word, disturbance, quotation,
# Nearest to so: girardeau, unpaved, dollfuss, elder, professional, change, too, running,
# Average loss at step  22000 :  6.960592696070671
# Average loss at step  24000 :  6.902259543061256
# Average loss at step  26000 :  6.790017468571663
# Average loss at step  28000 :  6.3701882658004765
# Average loss at step  30000 :  5.963309934139252
# Nearest to b: d, trench, and, identities, conductor, vogt, batll, gentiles,
# Nearest to four: six, eight, five, seven, three, nine, two, zero,
# Nearest to nine: eight, seven, six, four, five, zero, three, dasyprocta,
# Nearest to can: would, unlikely, specimens, could, to, bracelet, quite, may,
# Nearest to on: in, unwittingly, at, from, operatorname, two, for, by,
# Nearest to had: was, have, has, were, is, did, agouti, phi,
# Nearest to for: in, with, and, of, to, including, dasyprocta, from,
# Nearest to has: had, was, is, have, bequest, earths, ecclesia, kenneth,
# Nearest to the: its, their, this, his, a, abet, alphorn, aberdeenshire,
# Nearest to this: the, it, which, a, sponsors, lymphoma, aries, operatorname,
# Nearest to i: legality, stock, lymphoma, dasyprocta, claude, owners, safe, eduard,
# Nearest to history: appoint, originates, dasyprocta, apologia, commercials, luther, abdomen, worried,
# Nearest to time: shift, dasyprocta, agouti, cistercian, weishaupt, abet, phi, fathers,
# Nearest to use: aorta, serfdom, circ, coke, bckgr, stick, operatorname, enrich,
# Nearest to during: in, at, abet, of, judge, cell, and, by,
# Nearest to so: girardeau, unpaved, dollfuss, too, elder, presentation, junior, dci,
# Average loss at step  32000 :  6.009782461762429
# Average loss at step  34000 :  5.699526255607605
# Average loss at step  36000 :  5.754367060780525
# Average loss at step  38000 :  5.4910083810091015
# Average loss at step  40000 :  5.260060886859894
# Nearest to b: d, trench, zero, conductor, and, vma, batll, gentiles,
# Nearest to four: six, five, three, eight, seven, zero, two, one,
# Nearest to nine: eight, zero, seven, six, five, four, three, agouti,
# Nearest to can: would, may, will, could, specimens, unlikely, bracelet, should,
# Nearest to on: in, at, from, operatorname, unwittingly, two, apatosaurus, upon,
# Nearest to had: has, was, have, were, did, agouti, is, phi,
# Nearest to for: to, of, in, or, with, including, zero, dasyprocta,
# Nearest to has: had, was, is, have, bequest, became, ecclesia, were,
# Nearest to the: their, its, his, alphorn, this, operatorname, zero, a,
# Nearest to this: it, the, which, that, a, sponsors, lymphoma, operatorname,
# Nearest to i: legality, stock, claude, lymphoma, dasyprocta, UNK, eduard, safe,
# Nearest to history: appoint, dasyprocta, apologia, originates, commercials, abdomen, unit, masonic,
# Nearest to time: shift, dasyprocta, recitative, agouti, cistercian, weishaupt, phi, gland,
# Nearest to use: aorta, circ, serfdom, coke, bckgr, stick, operatorname, vma,
# Nearest to during: in, at, abet, of, judge, quotation, word, by,
# Nearest to so: girardeau, unpaved, too, dollfuss, elder, lunatic, junior, abingdon,
# Average loss at step  42000 :  5.3657195084095
# Average loss at step  44000 :  5.276364045619965
# Average loss at step  46000 :  5.226280478835106
# Average loss at step  48000 :  5.258946081876755
# Average loss at step  50000 :  4.999474687337876
# Nearest to b: d, trench, conductor, vma, hawaiian, agouti, batll, gentiles,
# Nearest to four: three, six, five, seven, eight, two, one, dasyprocta,
# Nearest to nine: eight, six, seven, zero, five, three, four, agouti,
# Nearest to can: would, will, may, could, should, must, specimens, to,
# Nearest to on: in, at, two, upon, operatorname, from, agouti, apatosaurus,
# Nearest to had: has, have, was, were, is, did, agouti, phi,
# Nearest to for: in, of, dasyprocta, or, to, with, agouti, abet,
# Nearest to has: had, was, is, have, bequest, ecclesia, became, were,
# Nearest to the: their, its, his, a, this, alphorn, lymphoma, operatorname,
# Nearest to this: it, which, the, sponsors, that, lymphoma, apatosaurus, any,
# Nearest to i: legality, eduard, dasyprocta, stock, lymphoma, claude, owners, reeds,
# Nearest to history: appoint, mangeshkar, dasyprocta, apologia, originates, commercials, unit, lymphoma,
# Nearest to time: dasyprocta, shift, recitative, cistercian, agouti, gland, weishaupt, fathers,
# Nearest to use: aorta, kapoor, circ, bckgr, coke, serfdom, stick, operatorname,
# Nearest to during: in, at, abet, of, after, through, fingerprints, word,
# Nearest to so: girardeau, unpaved, too, dollfuss, dci, presentation, elder, running,
# Average loss at step  52000 :  5.007573328495026
# Average loss at step  54000 :  5.196195202827454
# Average loss at step  56000 :  5.0625486959218975
# Average loss at step  58000 :  5.035933815360069
# Average loss at step  60000 :  4.938639921069146
# Nearest to b: d, trench, conductor, vma, hawaiian, batll, hagar, contrasting,
# Nearest to four: five, six, three, eight, seven, two, nine, zero,
# Nearest to nine: eight, six, seven, four, five, zero, ursus, vma,
# Nearest to can: would, may, could, will, should, must, if, specimens,
# Nearest to on: in, at, upon, unwittingly, operatorname, from, apatosaurus, two,
# Nearest to had: has, have, was, were, agouti, microsite, did, kifl,
# Nearest to for: of, in, to, or, at, dasyprocta, including, pulau,
# Nearest to has: had, have, was, is, bequest, ecclesia, subjected, became,
# Nearest to the: their, its, abet, alphorn, a, recitative, operatorname, this,
# Nearest to this: which, it, the, that, sponsors, lymphoma, operatorname, any,
# Nearest to i: legality, eduard, dasyprocta, owners, lymphoma, reeds, claude, neutron,
# Nearest to history: mangeshkar, appoint, dasyprocta, apologia, unit, commercials, budweiser, originates,
# Nearest to time: dasyprocta, shift, recitative, weishaupt, gland, cistercian, agouti, but,
# Nearest to use: wct, kapoor, aorta, circ, bckgr, coke, stick, serfdom,
# Nearest to during: in, at, abet, after, through, of, before, fingerprints,
# Nearest to so: too, girardeau, unpaved, pulau, dci, dollfuss, presentation, elder,
# Average loss at step  62000 :  4.993081521868706
# Average loss at step  64000 :  4.848159034848213
# Average loss at step  66000 :  4.594367680311203
# Average loss at step  68000 :  5.0092518502473835
# Average loss at step  70000 :  4.888807513952255
# Nearest to b: d, trench, vma, shanghainese, conductor, UNK, thaler, hawaiian,
# Nearest to four: five, six, three, eight, seven, two, nine, one,
# Nearest to nine: eight, six, seven, five, zero, four, three, ursus,
# Nearest to can: would, may, could, will, must, should, might, if,
# Nearest to on: upon, in, at, upanija, operatorname, unwittingly, agouti, from,
# Nearest to had: has, have, was, were, since, agouti, microsite, did,
# Nearest to for: jhanas, of, including, dasyprocta, and, in, analogs, pulau,
# Nearest to has: had, have, was, is, bequest, ecclesia, upanija, denials,
# Nearest to the: their, its, his, this, a, upanija, thaler, recitative,
# Nearest to this: which, it, the, that, sponsors, microcebus, there, any,
# Nearest to i: eduard, legality, claude, owners, dasyprocta, x, ectopic, we,
# Nearest to history: mangeshkar, appoint, commercials, callithrix, apologia, dasyprocta, budweiser, lymphoma,
# Nearest to time: thaler, dasyprocta, shift, microcebus, weishaupt, recitative, gland, agouti,
# Nearest to use: wct, kapoor, circ, aorta, coke, bckgr, ramps, reuptake,
# Nearest to during: in, at, abet, after, through, before, thaler, word,
# Nearest to so: upanija, girardeau, too, unpaved, elder, lunatic, pulau, dollfuss,
# Average loss at step  72000 :  4.768232102274895
# Average loss at step  74000 :  4.800461728930474
# Average loss at step  76000 :  4.721190515637398
# Average loss at step  78000 :  4.809804219216108
# Average loss at step  80000 :  4.805918367803097
# Nearest to b: d, trench, vma, UNK, shanghainese, conductor, m, thaler,
# Nearest to four: six, five, seven, three, eight, nine, two, zero,
# Nearest to nine: eight, six, seven, five, four, zero, ursus, thaler,
# Nearest to can: may, would, will, could, must, should, might, if,
# Nearest to on: upon, in, at, unwittingly, operatorname, and, upanija, agouti,
# Nearest to had: has, have, was, were, since, microsite, agouti, did,
# Nearest to for: jhanas, dasyprocta, in, including, pulau, of, to, thaler,
# Nearest to has: had, have, was, is, bequest, ecclesia, denials, upanija,
# Nearest to the: their, upanija, its, thaler, busan, a, ssbn, his,
# Nearest to this: it, which, that, the, any, sponsors, there, microcebus,
# Nearest to i: UNK, eduard, legality, claude, we, dasyprocta, you, ectopic,
# Nearest to history: mangeshkar, appoint, apologia, commercials, unit, transcendent, dasyprocta, callithrix,
# Nearest to time: thaler, dasyprocta, recitative, microcebus, shift, gland, agouti, weishaupt,
# Nearest to use: wct, kapoor, circ, aorta, coke, bckgr, ramps, reuptake,
# Nearest to during: in, at, abet, through, after, before, busan, when,
# Nearest to so: upanija, too, girardeau, unpaved, running, elder, mentality, abingdon,
# Average loss at step  82000 :  4.780850006699562
# Average loss at step  84000 :  4.749684528827667
# Average loss at step  86000 :  4.772151454091072
# Average loss at step  88000 :  4.74542267203331
# Average loss at step  90000 :  4.722528202056885
# Nearest to b: d, trench, shanghainese, m, vma, conductor, UNK, c,
# Nearest to four: five, three, seven, eight, six, two, one, nine,
# Nearest to nine: eight, seven, six, five, four, zero, three, ursus,
# Nearest to can: may, would, will, could, must, should, might, if,
# Nearest to on: upon, in, at, unwittingly, operatorname, upanija, under, agouti,
# Nearest to had: has, have, was, were, since, microsite, agouti, did,
# Nearest to for: jhanas, including, deianira, in, when, with, analogs, dasyprocta,
# Nearest to has: had, have, is, was, bequest, denials, ecclesia, lung,
# Nearest to the: its, their, upanija, this, a, his, aberdeenshire, busan,
# Nearest to this: it, which, the, that, any, some, microcebus, there,
# Nearest to i: eduard, UNK, you, we, legality, claude, ectopic, dasyprocta,
# Nearest to history: mangeshkar, apologia, appoint, dasyprocta, unit, callithrix, transcendent, commercials,
# Nearest to time: thaler, shift, dasyprocta, microcebus, recitative, weishaupt, guaranteed, gland,
# Nearest to use: wct, kapoor, circ, aorta, reuptake, bckgr, ramps, busan,
# Nearest to during: in, after, at, abet, through, when, before, globemaster,
# Nearest to so: upanija, too, girardeau, unpaved, addington, running, elder, dci,
# Average loss at step  92000 :  4.670754298210144
# Average loss at step  94000 :  4.726591574430466
# Average loss at step  96000 :  4.682773068308831
# Average loss at step  98000 :  4.606525927066803
# Average loss at step  100000 :  4.6846541355848315
# Nearest to b: d, trench, shanghainese, c, vma, conductor, m, thaler,
# Nearest to four: five, seven, three, six, eight, two, zero, nine,
# Nearest to nine: eight, seven, six, zero, five, four, ursus, three,
# Nearest to can: may, would, could, will, must, should, might, if,
# Nearest to on: upon, in, at, unwittingly, operatorname, upanija, apatosaurus, under,
# Nearest to had: has, have, was, were, since, microsite, agouti, arthropod,
# Nearest to for: jhanas, including, deianira, in, when, analogs, of, thaler,
# Nearest to has: had, have, was, is, ecclesia, bequest, includes, since,
# Nearest to the: its, their, this, a, his, upanija, busan, thaler,
# Nearest to this: it, which, the, some, that, any, microcebus, there,
# Nearest to i: we, you, legality, claude, eduard, ectopic, x, ii,
# Nearest to history: mangeshkar, dasyprocta, apologia, appoint, wct, lymphoma, callithrix, commercials,
# Nearest to time: recitative, thaler, shift, dasyprocta, microcebus, gland, agouti, guaranteed,
# Nearest to use: wct, kapoor, circ, aorta, ramps, bckgr, reuptake, busan,
# Nearest to during: in, after, at, through, abet, before, globemaster, when,
# Nearest to so: upanija, too, girardeau, addington, unpaved, dci, elder, brokers,

# %%
def plot_with_labels(low_dim_embs, labels, filename='tsne.png'):
  assert low_dim_embs.shape[0] >= len(labels), 'More labels than embeddings'
  plt.figure(figsize=(18, 18))  # in inches
  for i, label in enumerate(labels):
    x, y = low_dim_embs[i, :]
    plt.scatter(x, y)
    plt.annotate(label,
                 xy=(x, y),
                 xytext=(5, 2),
                 textcoords='offset points',
                 ha='right',
                 va='bottom')

  plt.savefig(filename)

try:
  # pylint: disable=g-import-not-at-top
  from sklearn.manifold import TSNE
  import matplotlib.pyplot as plt

  tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
  plot_only = 500
  low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only, :])
  labels = [reverse_dictionary[i] for i in xrange(plot_only)]
  plot_with_labels(low_dim_embs, labels)

except ImportError:
  print('Please install sklearn, matplotlib, and scipy to show embeddings.')
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:986: FutureWarning: The PCA initialization in TSNE will change to have the standard deviation of PC1 equal to 1e-4 in 1.2. This will ensure better convergence.
#   FutureWarning,
